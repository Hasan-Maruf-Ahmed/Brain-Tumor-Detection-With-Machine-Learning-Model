# %%
import torch

# %%
if torch.cuda.is_available():
    print(f"Using device: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available. Using CPU.")
# Out:
# Using device: NVIDIA GeForce RTX 4060

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

results = model.train(
    data="Brain Tumor V3/data.yaml",
    epochs=120,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:03<00:00, 5.65MB/s]
# Ultralytics 8.3.158  Python-3.13.5 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")

results = model.train(
    data="Brain Tumor V3/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:12<00:00, 4.16MB/s]
# Ultralytics 8.3.158  Python-3.13.5 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
from IPython.display import Image

Image(filename=f'runs/detect/train/results.png', width=1200)

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")

results = model.predict(source="Brain Tumor V3/test/images", show=True, save=False, conf=0.25)
# Out:
# image 1/425 g:\My Programming files\Python dev\Machine Learning Project Final Year\Brain Tumor V3\test\images\gg-134-_jpg.rf.07d0c727d6a270c7b5dd1fcdbc1b3997.jpg: 640x640 2 tumors, 69.8ms
# image 2/425 g:\My Programming files\Python dev\Machine Learning Project Final Year\Brain Tumor V3\test\images\gg-140-_jpg.rf.23ee36353c55d7f6aa9bf67437fab10e.jpg: 640x640 1 tumor, 95.1ms
# image 3/425 g:\My Programming files\Python dev\Machine Learning Project Final Year\Brain Tumor V3\test\images\gg-141-_jpg.rf.b06baac22b9a8fb0807d0e0163e0f75e.jpg: 640x640 (no detections), 65.7ms
# image 4/425 g:\My Programming files\Python dev\Machine Learning Project Final Year\Brain Tumor V3\test\images\gg-143-_jpg.rf.fb6b36dee22a22512e768b068b185872.jpg: 640x640 1 tumor, 78.7ms
# image 5/425 g:\My Programming files\Python dev\Machine Learning Project Final Year\Brain Tumor V3\test\images\gg-145-_jpg.rf.637941c7fbaacc981191e69525a09224.jpg: 640x640 1 tumor, 96.1ms
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

results = model.train(
    data="Brain Tumor V5/data.yaml",
    epochs=100,
    imgsz=640,
    batch=24,
    device=0
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.159 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.158  Python-3.13.5 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
from IPython.display import Image

Image(filename=f'runs/detect/train3/results.png', width=1200)
